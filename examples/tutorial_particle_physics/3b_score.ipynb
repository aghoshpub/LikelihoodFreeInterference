# %% [markdown]
# # MadMiner particle physics tutorial
#
# # Part 3b: Training a score estimator
#
# Johann Brehmer, Felix Kling, Irina Espejo, and Kyle Cranmer 2018-2019

# %% [markdown]
# In part 3a of this tutorial we will finally train a neural network to estimate likelihood ratios. We assume that you have run part 1 and 2a of this tutorial. If, instead of 2a, you have run part 2b, you just have to load a different filename later.

# %% [markdown]
# ## Preparations

# %% [markdown]
# Make sure you've run the first tutorial before executing this notebook!

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import logging
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

from madminer.sampling import SampleAugmenter
from madminer import sampling
from madminer.ml import ScoreEstimator

# %%
# MadMiner output
logging.basicConfig(
    format='%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s',
    datefmt='%H:%M',
    level=logging.INFO
)

# Output of all other modules (e.g. matplotlib)
for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

# %% [markdown]
# ## 1. Make (unweighted) training and test samples with augmented data

# %% [markdown]
# At this point, we have all the information we need from the simulations. But the data is not quite ready to be used for machine learning. The `madminer.sampling` class `SampleAugmenter` will take care of the remaining book-keeping steps before we can train our estimators:
#
# First, it unweights the samples, i.e. for a given parameter vector `theta` (or a distribution `p(theta)`) it picks events `x` such that their distribution follows `p(x|theta)`. The selected samples will all come from the event file we have so far, but their frequency is changed -- some events will appear multiple times, some will disappear.
#
# Second, `SampleAugmenter` calculates all the augmented data ("gold") that is the key to our new inference methods. Depending on the specific technique, these are the joint likelihood ratio and / or the joint score. It saves all these pieces of information for the selected events in a set of numpy files that can easily be used in any machine learning framework.

# %%
#sampler = SampleAugmenter('data/lhe_data_shuffled.h5')
sampler = SampleAugmenter('data/delphes_data_shuffled.h5')
# Out:
# 13:23 madminer.analysis    INFO    Loading data from data/delphes_data_shuffled.h5
# 13:23 madminer.analysis    INFO    Found 2 parameters
# 13:23 madminer.analysis    INFO    Did not find nuisance parameters
# 13:23 madminer.analysis    INFO    Found 6 benchmarks, of which 6 physical
# 13:23 madminer.analysis    INFO    Found 3 observables
# 13:23 madminer.analysis    INFO    Found 2063318 events
# 13:23 madminer.analysis    INFO      425909 signal events sampled from benchmark sm
# 13:23 madminer.analysis    INFO      368488 signal events sampled from benchmark w
# 13:23 madminer.analysis    INFO      397109 signal events sampled from benchmark neg_w
# 13:23 madminer.analysis    INFO      437740 signal events sampled from benchmark ww
# 13:23 madminer.analysis    INFO      434072 signal events sampled from benchmark neg_ww
# 13:23 madminer.analysis    INFO    Found morphing setup with 6 components
# 13:23 madminer.analysis    INFO    Did not find nuisance morphing setup

# %% [markdown]
# The relevant `SampleAugmenter` function for local score estimators is `extract_samples_train_local()`. As in part 3a of the tutorial, for the argument `theta` you can use the helper functions `sampling.benchmark()`, `sampling.benchmarks()`, `sampling.morphing_point()`, `sampling.morphing_points()`, and `sampling.random_morphing_points()`.

# %%
x, theta, t_xz, _ = sampler.sample_train_local(
    theta=sampling.benchmark('sm'),
    #n_samples=100000,
    n_samples=10**6,
    folder='./data/samples',
    filename='train_score'
)
# Out:
# 13:23 madminer.sampling    INFO    Extracting training sample for local score regression. Sampling and score evaluation according to sm
# 13:23 madminer.sampling    INFO    Starting sampling serially
# 13:23 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 13:23 madminer.sampling    INFO    Effective number of samples: mean 255113.99999999997, with individual thetas ranging from 255113.99999999988 to 255113.99999999988

# %% [markdown]
# We can use the same data as in part 3a, so you only have to execute this if you haven't gone through tutorial 3a:

# %%
_ = sampler.sample_test(
    theta=sampling.benchmark('sm'),
    n_samples=1000,
    folder='./data/samples',
    filename='test'
)
# Out:
# 13:23 madminer.sampling    INFO    Extracting evaluation sample. Sampling according to sm
# 13:23 madminer.sampling    INFO    Starting sampling serially
# 13:23 madminer.sampling    INFO    Sampling from parameter point 1 / 1
# 13:23 madminer.sampling    INFO    Effective number of samples: mean 85523.99999999999, with individual thetas ranging from 85523.99999999999 to 85523.99999999999

# %% [markdown]
# ## 2. Train score estimator

# %% [markdown]
# It's now time to build a neural network. Only this time, instead of the likelihood ratio itself, we will estimate the gradient of the log likelihood with respect to the theory parameters -- the score. To be precise, the output of the neural network is an estimate of the score at some reference parameter point, for instance the Standard Model. A neural network that estimates this "local" score can be used to calculate the Fisher information at that point. The estimated score can also be used as a machine learning version of Optimal Observables, and likelihoods can be estimated based on density estimation in the estimated score space. This method for likelihood ratio estimation is called SALLY, and there is a closely related version called SALLINO. Both are explained in ["Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00013) and ["A Guide to Constraining Effective Field Theories With Machine Learning"](https://arxiv.org/abs/1805.00020).
#
# The central object for this is the `madminer.ml.ScoreEstimator` class:

# %%
estimator = ScoreEstimator(n_hidden=(50,))

# %%
estimator.train(
    method='sally',
    x='data/samples/x_train_score.npy',
    t_xz='data/samples/t_xz_train_score.npy',
)

estimator.save('models/sally')
# Out:
# 13:23 madminer.ml          INFO    Starting training
# 13:23 madminer.ml          INFO      Batch size:             128
# 13:23 madminer.ml          INFO      Optimizer:              amsgrad
# 13:23 madminer.ml          INFO      Epochs:                 50
# 13:23 madminer.ml          INFO      Learning rate:          0.001 initially, decaying to 0.0001
# 13:23 madminer.ml          INFO      Validation split:       0.25
# 13:23 madminer.ml          INFO      Early stopping:         True
# 13:23 madminer.ml          INFO      Scale inputs:           True
# 13:23 madminer.ml          INFO      Shuffle labels          False
# 13:23 madminer.ml          INFO      Samples:                all
# 13:23 madminer.ml          INFO    Loading training data
# 13:23 madminer.utils.vario INFO      Loading data/samples/x_train_score.npy into RAM
# 13:23 madminer.utils.vario INFO      Loading data/samples/t_xz_train_score.npy into RAM
# 13:23 madminer.ml          INFO    Found 1000000 samples with 2 parameters and 3 observables
# 13:23 madminer.ml          INFO    Setting up input rescaling
# 13:23 madminer.ml          INFO    Creating model
# 13:23 madminer.ml          INFO    Training model
# 13:23 madminer.utils.ml.tr INFO    Training on CPU with single precision
# 13:24 madminer.utils.ml.tr INFO    Epoch   3: train loss  0.26160 (mse_score:  0.262)
# 13:24 madminer.utils.ml.tr INFO               val. loss   0.26013 (mse_score:  0.260)
# 13:25 madminer.utils.ml.tr INFO    Epoch   6: train loss  0.25593 (mse_score:  0.256)
# 13:25 madminer.utils.ml.tr INFO               val. loss   0.25511 (mse_score:  0.255)
# 13:26 madminer.utils.ml.tr INFO    Epoch   9: train loss  0.25250 (mse_score:  0.253)
# 13:26 madminer.utils.ml.tr INFO               val. loss   0.25148 (mse_score:  0.251)
# 13:27 madminer.utils.ml.tr INFO    Epoch  12: train loss  0.25049 (mse_score:  0.250)
# 13:27 madminer.utils.ml.tr INFO               val. loss   0.24955 (mse_score:  0.250)
# 13:29 madminer.utils.ml.tr INFO    Epoch  15: train loss  0.24920 (mse_score:  0.249)
# 13:29 madminer.utils.ml.tr INFO               val. loss   0.24920 (mse_score:  0.249)
# 13:30 madminer.utils.ml.tr INFO    Epoch  18: train loss  0.24821 (mse_score:  0.248)
# 13:30 madminer.utils.ml.tr INFO               val. loss   0.24781 (mse_score:  0.248)
# 13:31 madminer.utils.ml.tr INFO    Epoch  21: train loss  0.24747 (mse_score:  0.247)
# 13:31 madminer.utils.ml.tr INFO               val. loss   0.24696 (mse_score:  0.247)
# 13:32 madminer.utils.ml.tr INFO    Epoch  24: train loss  0.24684 (mse_score:  0.247)
# 13:32 madminer.utils.ml.tr INFO               val. loss   0.24698 (mse_score:  0.247)
# 13:33 madminer.utils.ml.tr INFO    Epoch  27: train loss  0.24633 (mse_score:  0.246)
# 13:33 madminer.utils.ml.tr INFO               val. loss   0.24660 (mse_score:  0.247)
# 13:34 madminer.utils.ml.tr INFO    Epoch  30: train loss  0.24597 (mse_score:  0.246)
# 13:34 madminer.utils.ml.tr INFO               val. loss   0.24599 (mse_score:  0.246)
# 13:36 madminer.utils.ml.tr INFO    Epoch  33: train loss  0.24559 (mse_score:  0.246)
# 13:36 madminer.utils.ml.tr INFO               val. loss   0.24597 (mse_score:  0.246)
# 13:37 madminer.utils.ml.tr INFO    Epoch  36: train loss  0.24525 (mse_score:  0.245)
# 13:37 madminer.utils.ml.tr INFO               val. loss   0.24565 (mse_score:  0.246)
# 13:38 madminer.utils.ml.tr INFO    Epoch  39: train loss  0.24506 (mse_score:  0.245)
# 13:38 madminer.utils.ml.tr INFO               val. loss   0.24493 (mse_score:  0.245)
# 13:39 madminer.utils.ml.tr INFO    Epoch  42: train loss  0.24482 (mse_score:  0.245)
# 13:39 madminer.utils.ml.tr INFO               val. loss   0.24518 (mse_score:  0.245)
# 13:40 madminer.utils.ml.tr INFO    Epoch  45: train loss  0.24466 (mse_score:  0.245)
# 13:40 madminer.utils.ml.tr INFO               val. loss   0.24477 (mse_score:  0.245)
# 13:42 madminer.utils.ml.tr INFO    Epoch  48: train loss  0.24445 (mse_score:  0.244)
# 13:42 madminer.utils.ml.tr INFO               val. loss   0.24483 (mse_score:  0.245)
# 13:42 madminer.utils.ml.tr INFO    Early stopping did not improve performance
# 13:42 madminer.utils.ml.tr INFO    Training time spend on:
# 13:42 madminer.utils.ml.tr INFO                      initialize model:   0.00h
# 13:42 madminer.utils.ml.tr INFO                                   ALL:   0.33h
# 13:42 madminer.utils.ml.tr INFO                            check data:   0.00h
# 13:42 madminer.utils.ml.tr INFO                          make dataset:   0.00h
# 13:42 madminer.utils.ml.tr INFO                       make dataloader:   0.00h
# 13:42 madminer.utils.ml.tr INFO                       setup optimizer:   0.00h
# 13:42 madminer.utils.ml.tr INFO                   initialize training:   0.00h
# 13:42 madminer.utils.ml.tr INFO                                set lr:   0.00h
# 13:42 madminer.utils.ml.tr INFO                   load training batch:   0.12h
# 13:42 madminer.utils.ml.tr INFO                        fwd: move data:   0.02h
# 13:42 madminer.utils.ml.tr INFO                   fwd: check for nans:   0.04h
# 13:42 madminer.utils.ml.tr INFO                    fwd: model.forward:   0.02h
# 13:42 madminer.utils.ml.tr INFO                 fwd: calculate losses:   0.01h
# 13:42 madminer.utils.ml.tr INFO                 training forward pass:   0.06h
# 13:42 madminer.utils.ml.tr INFO                   training sum losses:   0.01h
# 13:42 madminer.utils.ml.tr INFO                        opt: zero grad:   0.00h
# 13:42 madminer.utils.ml.tr INFO                         opt: backward:   0.03h
# 13:42 madminer.utils.ml.tr INFO                   opt: clip grad norm:   0.00h
# 13:42 madminer.utils.ml.tr INFO                             opt: step:   0.03h
# 13:42 madminer.utils.ml.tr INFO                        optimizer step:   0.07h
# 13:42 madminer.utils.ml.tr INFO                 load validation batch:   0.03h
# 13:42 madminer.utils.ml.tr INFO               validation forward pass:   0.02h
# 13:42 madminer.utils.ml.tr INFO                 validation sum losses:   0.00h
# 13:42 madminer.utils.ml.tr INFO                        early stopping:   0.00h
# 13:42 madminer.utils.ml.tr INFO                          report epoch:   0.00h
# 13:42 madminer.ml          INFO    Saving model to models/sally

# %% [markdown]
# ## 3. Evaluate score estimator

# %% [markdown]
# Let's evaluate the SM score on the test data

# %%
estimator.load('models/sally')

t_hat = estimator.evaluate_score(
    x='data/samples/x_test.npy'
)
# Out:
# 13:42 madminer.ml          INFO    Loading model from models/sally
# 13:42 madminer.utils.vario INFO      Loading data/samples/x_test.npy into RAM
# 13:42 madminer.ml          INFO    Starting score evaluation

# %% [markdown]
# Let's have a look at the estimated score and how it is related to the observables:

# %%
x = np.load('data/samples/x_test.npy')

fig = plt.figure(figsize=(10,4))

for i in range(2):
    
    ax = plt.subplot(1,2,i+1)

    sc = plt.scatter(x[:,0], x[:,1], c=t_hat[:,i], s=25., cmap='viridis', vmin=-1., vmax=1.)
    cbar = plt.colorbar(sc)

    cbar.set_label(r'$\hat{t}_' + str(i) + r'(x | \theta_{ref})$')
    plt.xlabel(r'$p_{T,j1}$ [GeV]')
    plt.ylabel(r'$\Delta \phi_{jj}$')
    plt.xlim(10.,300.)
    plt.ylim(-3.15,3.15)
    
plt.tight_layout()
plt.show()
